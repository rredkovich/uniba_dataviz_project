# %%
import pandas as pd

# %%
data_table = pd.read_csv("gut_taxonomic_table.csv")
metadata_table = pd.read_csv("sample_data.csv")
# Out:
# /var/folders/0_/qz2xxbkx40bf3ms9hkck6vjr0000gp/T/ipykernel_43300/3642385561.py:2: DtypeWarning: Columns (0: title, 1: attribute_bmi, 2: attribute_sex, 3: attribute_pm_gastro_problems_other, 4: attribute_pm_shared_who_other, 5: attribute_vioscreen_juice_servings, 6: attribute_pm_shared_pcp_changes_what_unspecified, 7: attribute_vioscreen_activity_level, 8: attribute_subset_ibd, 9: attribute_vioscreen_pfatot, 10: attribute_vioscreen_omega3, 11: attribute_vioscreen_starch, 12: attribute_vioscreen_zinc, 13: attribute_setting, 14: attribute_vioscreen_fried_fish_servings, 15: attribute_vioscreen_eer, 16: attribute_vioscreen_thiamin, 17: attribute_vioscreen_grams, 18: attribute_vioscreen_totsugar, 19: attribute_pm_lifestyle_change_how_change_in_physical_environment_ie_adopting_or_getting_rid_of_a_pet_cleaning_more_or_less_often, 20: attribute_vioscreen_frt5_day, 21: attribute_vioscreen_alcohol_servings, 22: attribute_vioscreen_cholest, 23: attribute_vioscreen_totaltfa, 24: attribute_vioscre
# ...

# %%
data_table['run_accession'] = data_table['sample'].str.split('_').str[1]
display(data_table['run_accession'])
# Out:
# /var/folders/0_/qz2xxbkx40bf3ms9hkck6vjr0000gp/T/ipykernel_43300/1875838468.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data_table['run_accession'] = data_table['sample'].str.split('_').str[1]
# 0       ERR4371625
# 1       ERR4371626
# 2       ERR4371627
# 3       ERR4371628
# 4       ERR4371629
#            ...
# 4845    ERR6177040
# 4846    ERR6177041
# 4847    ERR6177042
# 4848    ERR6177043
# 4849    ERR6177044
# Name: run_accession, Length: 4850, dtype: object

# %%
data = data_table.merge(metadata_table, on='run_accession')

# %%
display(data['attribute_sex'])
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 4845    female
# 4846    female
# 4847    female
# 4848    female
# 4849    female
# Name: attribute_sex, Length: 4850, dtype: str
